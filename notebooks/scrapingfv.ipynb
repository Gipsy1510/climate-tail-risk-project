# %%
import pandas as pd
from pathlib import Path

sample_path = Path("data/raw/complete_sample.csv")
df = pd.read_csv(sample_path)

print(df.shape)
print(df.head())
print(df.columns.tolist())

print(df["year"].value_counts().sort_index())
print(df["news_date"].min(), df["news_date"].max())
